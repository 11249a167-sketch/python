# %% [markdown]
# <a href="https://colab.research.google.com/github/11249a167-sketch/python/blob/main/exp2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # AIM:Develop a Python program to checkwhether a given string  is palindrome or not and also count the number of occurrencesof each digit in the input number.

# %%
input_str = input("Enter a string: ")
if input_str == input_str[::-1]:
    print("Palindrome")
else:
    print("Not Palindrome")

for ch in set(input_str):
    count = input_str.count(ch)
    print(f"'{ch}' appears {count} times")
# Out:
# Enter a string: madam
# Palindrome
# 'm' appears 2 times
# 'a' appears 2 times
# 'd' appears 1 times

# %% [markdown]
# #RESULT:this program is exceuted succefull
